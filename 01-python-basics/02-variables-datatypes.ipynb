# %% [markdown]
# # Variables and Datatypes
# - variables - a container that stores data / memory space reserved in RAM
# - datatypes - data stored in variables can be of varied types
# - basic datatypes - integer, float, string, boolean ; advanced - lists, dictionaries, tuples, sets

# %%
userAge = 28 #integer - 8bits
userHeight = 5.7 #float - 16bits
userFirstName = "Vaibhav" #string
userLastName = "Patil" #string
isUserStudent = False #boolean

print("Age - ", userAge)
print("Height - ",userHeight)
print("First Name - ",userFirstName)
print("Last Name - ",userLastName)
print("Is User a student - ",isUserStudent)
# Out:
# Age -  28
# Height -  5.7
# First Name -  Vaibhav
# Last Name -  Patil
# Is User a student -  False

# %%
# Type checking

print("type of age - ",type(userAge)) 
print("type of height - ",type(userHeight))
print("type of first name - ",type(userFirstName))
print("type of last name - ",type(userLastName))
print("type of is user student - ",type(isUserStudent))
# Out:
# type of age -  <class 'int'>
# type of height -  <class 'float'>
# type of first name -  <class 'str'>
# type of last name -  <class 'str'>
# type of is user student -  <class 'bool'>

# %%
# Type Conversion/ Casting

userSalary = 20000 #integer

newTypeString = str(userSalary) #changing type to string
print(newTypeString)
print(type(newTypeString))

newTypeFloat = float(userSalary) #changing type to float
print(newTypeFloat)
print(type(newTypeFloat))
# Out:
# 20000
# <class 'str'>
# 20000.0
# <class 'float'>

# %%
# Dynamic typing - python allows the type of a variable to change as the program executes
var = 10
print(var, type(var))

var = "Hello"
print(var, type(var))

var = 10.10
print(var, type(var))
# Out:
# 10 <class 'int'>
# Hello <class 'str'>
# 10.1 <class 'float'>

# %%
# Taking input from user - by default input taken is string so we need to convert the type
age = int(input("What is you age"))
print(age, type(age))
# Out:
# 27 <class 'int'>

# %%
# Simple calculator
num1 = float(input("Enter first number = "))
num2 = float(input("Enter second number = "))

addition = num1 + num2
substraction = num1 - num2
multiplication = num1*num2
division = num1/num2

print("addition = ", addition)
print("substraction = ", substraction)
print("multiplication = ", multiplication)
print("division = ", division)
# Out:
# addition =  57.0
# substraction =  -7.0
# multiplication =  800.0
# division =  0.78125
