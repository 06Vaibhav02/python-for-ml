# %% [markdown]
# # Python Basics
# - python is case sensitive.
# - python is dynamically typed - the type of a variable is determined at runtime.

# %%
# this is single line comment
"""
this is multiline comment - does not work in notebook
"""
# Out:
# '\nthis is multiline comment\n'

# %%
# syntax and semantics 
"""
Syntax is the set of rules for a language's grammar and structure, determining if a statement is correctly formed, while semantics is the meaning of that statement.
"""
# Out:
# "\nSyntax is the set of rules for a language's grammar and structure, determining if a statement is correctly formed, while semantics is the meaning of that statement.\n"

# %%
print("hello world") #prints hello world
# Out:
# hello world

# %%
# indentation - 4spaces
if True:
    print("you are inside true")
    if False:
        print("you are inside false which is inside true")
# Out:
# you are inside true

# %%
# type inference/ type check
variable = 10
print(type(variable))
variable = "vaibhav"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>
