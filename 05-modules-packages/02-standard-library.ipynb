# %% [markdown]
# # Standard Library Overview
# - Python's Standard Library is a vast collection of modules and packages that come bundled with python,
# providing a wide range of functionalities out of the box. Here's an overview of some of the most commanly
# used modules and packages in python standard library

# %%
import array
new_array = array.array('i', [1,2,3,4])
print(new_array)
# Out:
# array('i', [1, 2, 3, 4])

# %%
import math
print(math.sqrt(25))
print(math.pi)
# Out:
# 5.0
# 3.141592653589793

# %%
import random
print(random.randint(1,10))
print(random.choice(['apple', 'banana', 'cherry', 'kiwi']))
# Out:
# 8
# kiwi

# %%
import os     #for file and directory access
print(os.getcwd()) #cwd - current workind directory
# Out:
# l:\artificial-intelligence\python-for-ml\05-modules-packages

# %%
os.mkdir('test_dir')

# %%
## High level operations on files and collection of files
import shutil
shutil.copyfile('source.txt', 'destination.txt')
# Out:
# 'destination.txt'

# %%
## Data Serialization
import json         #when interacting with API's return type is JSONString which we parse using loads()
data = {'name':'Vaibhav', 'age':25}

json_str = json.dumps(data)
print(json_str)
print(type(json_str)) 

parsed_data = json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "Vaibhav", "age": 25}
# <class 'str'>
# {'name': 'Vaibhav', 'age': 25}
# <class 'dict'>

# %%
## CSV
import csv

with open('example.csv', mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['name', 'age'])
    writer.writerow(['vaibhav', 28])

with open('example.csv', mode='r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['vaibhav', '28']

# %%
## datetime

from datetime import datetime, timedelta
